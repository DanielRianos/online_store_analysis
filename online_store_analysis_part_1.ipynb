# %% [markdown]
# # Data Exploration

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import pgeocode
from sklearn.neighbors import DistanceMetric
from math import radians
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data set 1: Olist Customers

# %%
data1_customers = pd.read_csv('data_sets/brazilian_e_commerce_public/1_olist_customers_dataset.csv')
data1_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
data1_customers.count()
# Out:
# customer_id                 99441
# customer_unique_id          99441
# customer_zip_code_prefix    99441
# customer_city               99441
# customer_state              99441
# dtype: int64

# %%
data1_customers.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='object')

# %%
data1_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
data1_customers = data1_customers.rename(columns={'customer_zip_code_prefix': 'zip_code_prefix'})

# %%
data1_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    zip_code_prefix          customer_city customer_state
# 0            14409                 franca             SP
# 1             9790  sao bernardo do campo             SP
# 2             1151              sao paulo             SP
# 3             8775        mogi das cruzes             SP
# 4            13056               campinas             SP

# %% [markdown]
# ### Data set 2: Olist Geolocation

# %%
data2_geolocation = pd.read_csv('data_sets/brazilian_e_commerce_public/2_olist_geolocation_dataset.csv')
data2_geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
data2_geolocation.count()
# Out:
# geolocation_zip_code_prefix    1000163
# geolocation_lat                1000163
# geolocation_lng                1000163
# geolocation_city               1000163
# geolocation_state              1000163
# dtype: int64

# %%
data2_geolocation.columns
# Out:
# Index(['geolocation_zip_code_prefix', 'geolocation_lat', 'geolocation_lng',
#        'geolocation_city', 'geolocation_state'],
#       dtype='object')

# %%
data2_geolocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
data2_geolocation = data2_geolocation.rename(columns={'geolocation_zip_code_prefix': 'zip_code_prefix'})

# %%
data2_geolocation.head()
# Out:
#    zip_code_prefix  geolocation_lat  geolocation_lng geolocation_city  \
# 0             1037       -23.545621       -46.639292        sao paulo
# 1             1046       -23.546081       -46.644820        sao paulo
# 2             1046       -23.546129       -46.642951        sao paulo
# 3             1041       -23.544392       -46.639499        sao paulo
# 4             1035       -23.541578       -46.641607        sao paulo
#
#   geolocation_state
# 0                SP
# 1                SP
# 2                SP
# 3                SP
# 4                SP

# %%
data2_geolocation2 = data2_geolocation.drop_duplicates(subset=['zip_code_prefix'])
data2_geolocation2 = data2_geolocation2.drop(columns=['geolocation_lat', 'geolocation_lng'])
data2_geolocation2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19015 entries, 0 to 999846
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   zip_code_prefix    19015 non-null  int64
#  1   geolocation_city   19015 non-null  object
#  2   geolocation_state  19015 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 594.2+ KB

# %%
data2_geolocation['zip_code_prefix'].unique()
# Out:
# array([ 1037,  1046,  1041, ..., 99910, 99920, 99952])

# %%
geolocation_lat= pd.DataFrame(data2_geolocation.groupby('zip_code_prefix')['geolocation_lat'].mean())
geolocation_lat
# Out:
#                  geolocation_lat
# zip_code_prefix
# 1001                  -23.550190
# 1002                  -23.548146
# 1003                  -23.548994
# 1004                  -23.549799
# 1005                  -23.549456
# ...                          ...
# 99960                 -27.953722
# 99965                 -28.183372
# 99970                 -28.343766
# 99980                 -28.389129
# 99990                 -28.329595
#
# [19015 rows x 1 columns]

# %%
geolocation_lng= pd.DataFrame(data2_geolocation.groupby('zip_code_prefix')['geolocation_lng'].mean())
geolocation_lng
# Out:
#                  geolocation_lng
# zip_code_prefix
# 1001                  -46.634024
# 1002                  -46.634979
# 1003                  -46.635731
# 1004                  -46.634757
# 1005                  -46.636733
# ...                          ...
# 99960                 -52.025511
# 99965                 -52.039850
# 99970                 -51.874689
# 99980                 -51.843836
# 99990                 -51.769362
#
# [19015 rows x 1 columns]

# %%
coordinates= geolocation_lat.merge(geolocation_lng, how='left',on= 'zip_code_prefix')
coordinates
# Out:
#                  geolocation_lat  geolocation_lng
# zip_code_prefix
# 1001                  -23.550190       -46.634024
# 1002                  -23.548146       -46.634979
# 1003                  -23.548994       -46.635731
# 1004                  -23.549799       -46.634757
# 1005                  -23.549456       -46.636733
# ...                          ...              ...
# 99960                 -27.953722       -52.025511
# 99965                 -28.183372       -52.039850
# 99970                 -28.343766       -51.874689
# 99980                 -28.389129       -51.843836
# 99990                 -28.329595       -51.769362
#
# [19015 rows x 2 columns]

# %%
data2_geolocation= data2_geolocation2.merge(coordinates, how='left',on= 'zip_code_prefix')

# %%
data2_geolocation.head()
# Out:
#    zip_code_prefix geolocation_city geolocation_state  geolocation_lat  \
# 0             1037        sao paulo                SP       -23.545411
# 1             1046        sao paulo                SP       -23.545930
# 2             1041        sao paulo                SP       -23.543905
# 3             1035        sao paulo                SP       -23.541614
# 4             1012        são paulo                SP       -23.547790
#
#    geolocation_lng
# 0       -46.638924
# 1       -46.643998
# 2       -46.640046
# 3       -46.641549
# 4       -46.634859

# %%
data1_customers= data1_customers.merge(data2_geolocation, how='left',on= 'zip_code_prefix')

# %%
data1_customers= data1_customers.drop(columns=['geolocation_city', 'geolocation_state'])

# %%
data1_customers = data1_customers.rename(columns={'zip_code_prefix': 'zip_code_prefix_customer','geolocation_lat': 'geolocation_lat_customer','geolocation_lng': 'geolocation_lng_customer'})

# %%
data1_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    zip_code_prefix_customer          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#    geolocation_lat_customer  geolocation_lng_customer
# 0                -20.498489                -47.396929
# 1                -23.727992                -46.542848
# 2                -23.531642                -46.656289
# 3                -23.499702                -46.185233
# 4                -22.975100                -47.142925

# %% [markdown]
# ### Data set 3: Olist Order Items

# %%
data3_items = pd.read_csv('data_sets/brazilian_e_commerce_public/3_olist_order_items_dataset.csv')
data3_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
data3_items.count()
# Out:
# order_id               112650
# order_item_id          112650
# product_id             112650
# seller_id              112650
# shipping_limit_date    112650
# price                  112650
# freight_value          112650
# dtype: int64

# %%
data3_items.columns
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='object')

# %%
data3_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
data3_items['shipping_limit_date']=  pd.to_datetime(data3_items['shipping_limit_date'])

# %%
data3_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
data3_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0 2017-09-19 09:45:35   58.90          13.29
# 1 2017-05-03 11:05:13  239.90          19.93
# 2 2018-01-18 14:48:30  199.00          17.87
# 3 2018-08-15 10:10:18   12.99          12.79
# 4 2017-02-13 13:57:51  199.90          18.14

# %%
data3_items['shipping_limit_date_only'] = data3_items['shipping_limit_date'].dt.strftime("%m-%d-%Y")

# %%
data3_items['shipping_limit_date_hour'] = data3_items['shipping_limit_date'].dt.time

# %%
data3_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value shipping_limit_date_only  \
# 0 2017-09-19 09:45:35   58.90          13.29               09-19-2017
# 1 2017-05-03 11:05:13  239.90          19.93               05-03-2017
# 2 2018-01-18 14:48:30  199.00          17.87               01-18-2018
# 3 2018-08-15 10:10:18   12.99          12.79               08-15-2018
# 4 2017-02-13 13:57:51  199.90          18.14               02-13-2017
#
#   shipping_limit_date_hour
# 0                 09:45:35
# 1                 11:05:13
# 2                 14:48:30
# 3                 10:10:18
# 4                 13:57:51

# %%
data3_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   order_id                  112650 non-null  object
#  1   order_item_id             112650 non-null  int64
#  2   product_id                112650 non-null  object
#  3   seller_id                 112650 non-null  object
#  4   shipping_limit_date       112650 non-null  datetime64[ns]
#  5   price                     112650 non-null  float64
#  6   freight_value             112650 non-null  float64
#  7   shipping_limit_date_only  112650 non-null  object
#  8   shipping_limit_date_hour  112650 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 7.7+ MB

# %%
data3_items['shipping_limit_date_only'] = pd.to_datetime(data3_items['shipping_limit_date_only'])

# %%
data3_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value shipping_limit_date_only  \
# 0 2017-09-19 09:45:35   58.90          13.29               2017-09-19
# 1 2017-05-03 11:05:13  239.90          19.93               2017-05-03
# 2 2018-01-18 14:48:30  199.00          17.87               2018-01-18
# 3 2018-08-15 10:10:18   12.99          12.79               2018-08-15
# 4 2017-02-13 13:57:51  199.90          18.14               2017-02-13
#
#   shipping_limit_date_hour
# 0                 09:45:35
# 1                 11:05:13
# 2                 14:48:30
# 3                 10:10:18
# 4                 13:57:51

# %%
data3_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   order_id                  112650 non-null  object
#  1   order_item_id             112650 non-null  int64
#  2   product_id                112650 non-null  object
#  3   seller_id                 112650 non-null  object
#  4   shipping_limit_date       112650 non-null  datetime64[ns]
#  5   price                     112650 non-null  float64
#  6   freight_value             112650 non-null  float64
#  7   shipping_limit_date_only  112650 non-null  datetime64[ns]
#  8   shipping_limit_date_hour  112650 non-null  object
# dtypes: datetime64[ns](2), float64(2), int64(1), object(4)
# memory usage: 7.7+ MB

# %% [markdown]
# ### Data set 4: Olist order payments

# %%
data4_payments= pd.read_csv('data_sets/brazilian_e_commerce_public/4_olist_order_payments_dataset.csv')
data4_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
data4_payments.count()
# Out:
# order_id                103886
# payment_sequential      103886
# payment_type            103886
# payment_installments    103886
# payment_value           103886
# dtype: int64

# %%
data4_payments.columns
# Out:
# Index(['order_id', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value'],
#       dtype='object')

# %%
data4_payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %% [markdown]
# ### Data set 5: Olist order reviews

# %%
data5_reviews= pd.read_csv('data_sets/brazilian_e_commerce_public/5_olist_order_reviews_dataset.csv')
data5_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
data5_reviews.count()
# Out:
# review_id                  99224
# order_id                   99224
# review_score               99224
# review_comment_title       11568
# review_comment_message     40977
# review_creation_date       99224
# review_answer_timestamp    99224
# dtype: int64

# %%
data5_reviews.columns
# Out:
# Index(['review_id', 'order_id', 'review_score', 'review_comment_title',
#        'review_comment_message', 'review_creation_date',
#        'review_answer_timestamp'],
#       dtype='object')

# %%
data5_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
data5_reviews['review_creation_date']=  pd.to_datetime(data5_reviews['review_creation_date'])
data5_reviews['review_answer_timestamp']=  pd.to_datetime(data5_reviews['review_answer_timestamp'])

# %%
data5_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN           2018-01-18
# 1                                                NaN           2018-03-10
# 2                                                NaN           2018-02-17
# 3              Recebi bem antes do prazo estipulado.           2017-04-21
# 4  Parabéns lojas lannister adorei comprar pela I...           2018-03-01
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
data5_reviews['review_answer_timestamp_date_only'] = data5_reviews['review_answer_timestamp'].dt.strftime("%m-%d-%Y")
data5_reviews['review_answer_timestamp_hour'] = data5_reviews['review_answer_timestamp'].dt.time

# %%
data5_reviews['review_answer_timestamp_date_only']= pd.to_datetime(data5_reviews['review_answer_timestamp_date_only'])

# %%
data5_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN           2018-01-18
# 1                                                NaN           2018-03-10
# 2                                                NaN           2018-02-17
# 3              Recebi bem antes do prazo estipulado.           2017-04-21
# 4  Parabéns lojas lannister adorei comprar pela I...           2018-03-01
#
#   review_answer_timestamp review_answer_timestamp_date_only  \
# 0     2018-01-18 21:46:59                        2018-01-18
# 1     2018-03-11 03:05:13                        2018-03-11
# 2     2018-02-18 14:36:24                        2018-02-18
# 3     2017-04-21 22:02:06                        2017-04-21
# 4     2018-03-02 10:26:53                        2018-03-02
#
#   review_answer_timestamp_hour
# 0                     21:46:59
# 1                     03:05:13
# 2                     14:36:24
# 3                     22:02:06
# 4                     10:26:53

# %%
data5_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 9 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   review_id                          99224 non-null  object
#  1   order_id                           99224 non-null  object
#  2   review_score                       99224 non-null  int64
#  3   review_comment_title               11568 non-null  object
#  4   review_comment_message             40977 non-null  object
#  5   review_creation_date               99224 non-null  datetime64[ns]
#  6   review_answer_timestamp            99224 non-null  datetime64[ns]
#  7   review_answer_timestamp_date_only  99224 non-null  datetime64[ns]
#  8   review_answer_timestamp_hour       99224 non-null  object
# dtypes: datetime64[ns](3), int64(1), object(5)
# memory usage: 6.8+ MB

# %%
data5_reviews['review_creation_answer_delta_hours']=  (data5_reviews['review_answer_timestamp']-data5_reviews['review_creation_date'])

# %%
data5_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN           2018-01-18
# 1                                                NaN           2018-03-10
# 2                                                NaN           2018-02-17
# 3              Recebi bem antes do prazo estipulado.           2017-04-21
# 4  Parabéns lojas lannister adorei comprar pela I...           2018-03-01
#
#   review_answer_timestamp review_answer_timestamp_date_only  \
# 0     2018-01-18 21:46:59                        2018-01-18
# 1     2018-03-11 03:05:13                        2018-03-11
# 2     2018-02-18 14:36:24                        2018-02-18
# 3     2017-04-21 22:02:06                        2017-04-21
# 4     2018-03-02 10:26:53                        2018-03-02
#
#   review_answer_timestamp_hour review_creation_answer_delta_hours
# 0                     21:46:59                    0 days 21:46:59
# 1                     03:05:13                    1 days 03:05:13
# 2                     14:36:24                    1 days 14:36:24
# 3                     22:02:06                    0 days 22:02:06
# 4                     10:26:53                    1 days 10:26:53

# %% [markdown]
# ### Data set 6: Olist Orders

# %%
data6_orders= pd.read_csv('data_sets/brazilian_e_commerce_public/6_olist_orders_dataset.csv')
data6_orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
data6_orders.count()
# Out:
# order_id                         99441
# customer_id                      99441
# order_status                     99441
# order_purchase_timestamp         99441
# order_approved_at                99281
# order_delivered_carrier_date     97658
# order_delivered_customer_date    96476
# order_estimated_delivery_date    99441
# dtype: int64

# %%
data6_orders.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='object')

# %%
data6_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
data6_orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
data6_orders = data6_orders.dropna()

# %%
data6_orders.isnull().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %%
data6_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96461 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       96461 non-null  object
#  1   customer_id                    96461 non-null  object
#  2   order_status                   96461 non-null  object
#  3   order_purchase_timestamp       96461 non-null  object
#  4   order_approved_at              96461 non-null  object
#  5   order_delivered_carrier_date   96461 non-null  object
#  6   order_delivered_customer_date  96461 non-null  object
#  7   order_estimated_delivery_date  96461 non-null  object
# dtypes: object(8)
# memory usage: 6.6+ MB

# %%
data6_orders['order_purchase_timestamp']=  pd.to_datetime(data6_orders['order_purchase_timestamp'])
data6_orders['order_approved_at']=  pd.to_datetime(data6_orders['order_approved_at'])
data6_orders['order_delivered_carrier_date']=  pd.to_datetime(data6_orders['order_delivered_carrier_date'])
data6_orders['order_delivered_customer_date']=  pd.to_datetime(data6_orders['order_delivered_customer_date'])
data6_orders['order_estimated_delivery_date']=  pd.to_datetime(data6_orders['order_estimated_delivery_date'])

# %%
data6_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96461 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       96461 non-null  object
#  1   customer_id                    96461 non-null  object
#  2   order_status                   96461 non-null  object
#  3   order_purchase_timestamp       96461 non-null  datetime64[ns]
#  4   order_approved_at              96461 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   96461 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96461 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  96461 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.6+ MB

# %%
data6_orders['delta_purchase_approved'] =  (data6_orders['order_approved_at'] - data6_orders['order_purchase_timestamp']).astype('timedelta64[h]')
data6_orders['delta_purchase_delivered_carrier'] = (data6_orders['order_delivered_carrier_date'] - data6_orders['order_purchase_timestamp']).astype('timedelta64[h]')
data6_orders['delta_purchase_delivered_customer'] =  (data6_orders['order_delivered_customer_date'] - data6_orders['order_purchase_timestamp']).astype('timedelta64[h]')
data6_orders['delta_delivered_customer_carrier'] = (data6_orders['order_delivered_customer_date'] -  data6_orders['order_delivered_carrier_date']).astype('timedelta64[h]')
data6_orders['delta_delivered_customer_order_estimated_delivery_'] = (data6_orders['order_estimated_delivery_date'] - data6_orders['order_delivered_customer_date']).astype('timedelta64[h]')

# %%
data6_orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date  delta_purchase_approved  \
# 0                    2017-10-18                      0.0
# 1                    2018-08-13                     30.0
# 2                    2018-09-04                      0.0
# 3                    2017-12-15                      0.0
# 4                    2018-02-26                      1.0
#
#    delta_purchase_delivered_carrier  delta_purchase_delivered_customer  \
# 0                              56.0                              202.0
# 1                              41.0                              330.0
# 2                               5.0                              225.0
# 3                              90.0                              317.0
# 4                              22.0                               68.0
#
#    delta_delivered_customer_carrier  \
# 0                             145.0
# 1                             288.0
# 2                             220.0
# 3                             226.0
# 4                              46.0
#
#    delta_delivered_customer_order_estimated_delivery_
# 0                                              170.0
# 1                                              128.0
# 2                                              413.0
# 3                                              311.0
# 4                                              221.0

# %%
data3_items.loc[data3_items['order_id'].isin(['e481f51cbdc54678b7cc49136f2d6af7','53cdb2fc8bc7dce0b6741e2150273451','47770eb9100c2d0c44946d9cf07ec65d','949d5b44dbf5de918fe9c16f97b45f8a','ad21c59c0840e6cb83a9ceb5573f8159'])]
# Out:
#                                 order_id  order_item_id  \
# 31504   47770eb9100c2d0c44946d9cf07ec65d              1
# 36896   53cdb2fc8bc7dce0b6741e2150273451              1
# 65021   949d5b44dbf5de918fe9c16f97b45f8a              1
# 76043   ad21c59c0840e6cb83a9ceb5573f8159              1
# 100785  e481f51cbdc54678b7cc49136f2d6af7              1
#
#                               product_id                         seller_id  \
# 31504   aa4383b373c6aca5d8797843e5594415  4869f7a5dfa277a7dca6462dcf3b52b2
# 36896   595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 65021   d0b61bfb1de832b15ba9d266ca96e5b0  66922902710d126a0e7d26b0e3805106
# 76043   65266b2da20d04dbe00c5c2d3bb7859e  2c9e548be18521d1c43cde1c582c6de8
# 100785  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
#
#        shipping_limit_date   price  freight_value shipping_limit_date_only  \
# 31504  2018-08-13 08:55:23  159.90          19.22               2018-08-13
# 36896  2018-07-30 03:24:27  118.70          22.76               2018-07-30
# 65021  2017-11-23 19:45:59   45.00          27.20               2017-11-23
# 76043  2018-02-19 20:31:37   19.90           8.72               2018-02-19
# 100785 2017-10-06 11:07:15   29.99           8.72               2017-10-06
#
#        shipping_limit_date_hour
# 31504                  08:55:23
# 36896                  03:24:27
# 65021                  19:45:59
# 76043                  20:31:37
# 100785                 11:07:15

# %% [markdown]
# ### Data set 7: Olist Products

# %%
data7_products= pd.read_csv('data_sets/brazilian_e_commerce_public/7_olist_products_dataset.csv')
data7_products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
data7_products.count()
# Out:
# product_id                    32951
# product_category_name         32341
# product_name_lenght           32341
# product_description_lenght    32341
# product_photos_qty            32341
# product_weight_g              32949
# product_length_cm             32949
# product_height_cm             32949
# product_width_cm              32949
# dtype: int64

# %%
data7_products.columns
# Out:
# Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='object')

# %%
data7_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# ### Data set 8: Olist sellers

# %%
data8_sellers= pd.read_csv('data_sets/brazilian_e_commerce_public/8_olist_sellers_dataset.csv')
data8_sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
data8_sellers.count()
# Out:
# seller_id                 3095
# seller_zip_code_prefix    3095
# seller_city               3095
# seller_state              3095
# dtype: int64

# %%
data8_sellers.columns
# Out:
# Index(['seller_id', 'seller_zip_code_prefix', 'seller_city', 'seller_state'], dtype='object')

# %%
data8_sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
data8_sellers = data8_sellers.rename(columns={'seller_zip_code_prefix': 'zip_code_prefix'})

# %%
data8_sellers= data8_sellers.merge(data2_geolocation, how='left',on= 'zip_code_prefix')

# %%
data8_sellers.head()
# Out:
#                           seller_id  zip_code_prefix        seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15            13023           campinas
# 1  d1b65fc7debc3361ea86b5f14c68d2e2            13844         mogi guacu
# 2  ce3ad9de960102d0677a81f5d0bb7b2d            20031     rio de janeiro
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3             4195          sao paulo
# 4  51a04a8a6bdcb23deccc82b0b80742cf            12914  braganca paulista
#
#   seller_state   geolocation_city geolocation_state  geolocation_lat  \
# 0           SP           campinas                SP       -22.893848
# 1           SP         mogi-guacu                SP       -22.383437
# 2           RJ     rio de janeiro                RJ       -22.909572
# 3           SP          sao paulo                SP       -23.657242
# 4           SP  bragança paulista                SP       -22.964803
#
#    geolocation_lng
# 0       -47.061337
# 1       -46.947927
# 2       -43.177703
# 3       -46.612831
# 4       -46.534419

# %%
data8_sellers= data8_sellers.drop(columns=['geolocation_city', 'geolocation_state'])

# %%
data8_sellers = data8_sellers.rename(columns={'zip_code_prefix': 'zip_code_prefix_seller','geolocation_lat': 'geolocation_lat_seller','geolocation_lng': 'geolocation_lng_seller'})

# %%
data8_sellers.head()
# Out:
#                           seller_id  zip_code_prefix_seller  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state  geolocation_lat_seller  \
# 0           campinas           SP              -22.893848
# 1         mogi guacu           SP              -22.383437
# 2     rio de janeiro           RJ              -22.909572
# 3          sao paulo           SP              -23.657242
# 4  braganca paulista           SP              -22.964803
#
#    geolocation_lng_seller
# 0              -47.061337
# 1              -46.947927
# 2              -43.177703
# 3              -46.612831
# 4              -46.534419

# %%
data8_sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3095 entries, 0 to 3094
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   zip_code_prefix_seller  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
#  4   geolocation_lat_seller  3088 non-null   float64
#  5   geolocation_lng_seller  3088 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 169.3+ KB

# %% [markdown]
# ### Data set 9: Product category name translation

# %%
data9_translation= pd.read_csv('data_sets/brazilian_e_commerce_public/9_product_category_name_translation.csv')
data9_translation.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
data9_translation.count()
# Out:
# product_category_name            71
# product_category_name_english    71
# dtype: int64

# %%
data9_translation.columns
# Out:
# Index(['product_category_name', 'product_category_name_english'], dtype='object')

# %%
data9_translation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
states_brazil_list = {'north_region':[('Acre','AC'),('Amapá','AP'),('Amazonas','AM'),('Pará','PA'),('Rondônia','RO'),('Roraima','RR'),('Tocantins','TO')],
                      'northeast': [('Alagoas','AL'),('Bahia','BA'),('Ceará','CE'),('Maranhão','MA'),('Paraíba','PB'),('Pernambuco','PE'), ('Piauí','PI'), ('Rio Grande do Norte','RN'), ('Sergipe','SE')],
                      'central_west':[('Goiás','GO'),('Mato Grosso','MT'),('Mato Grosso do Sul','MS'),('Brasília','DF')],
                      'southeast':[('Espírito Santo','ES'),('Minas Gerais','MG'),('Rio de Janeiro','RJ'),('São Paulo','SP')],
                      'south':[('Paraná','PR'),('Santa Catarina','SC'),('Rio Grande do Sul','RS')]}

# %%
regions_df1 = pd.DataFrame(states_brazil_list['north_region'], columns= ['state','sc_state'])
regions_df1['region']= 'north_region'
regions_df1
# Out:
#        state sc_state        region
# 0       Acre       AC  north_region
# 1      Amapá       AP  north_region
# 2   Amazonas       AM  north_region
# 3       Pará       PA  north_region
# 4   Rondônia       RO  north_region
# 5    Roraima       RR  north_region
# 6  Tocantins       TO  north_region

# %%
regions_df2 = pd.DataFrame(states_brazil_list['northeast'], columns= ['state','sc_state'])
regions_df2['region']= 'northeast'
regions_df2
# Out:
#                  state sc_state     region
# 0              Alagoas       AL  northeast
# 1                Bahia       BA  northeast
# 2                Ceará       CE  northeast
# 3             Maranhão       MA  northeast
# 4              Paraíba       PB  northeast
# 5           Pernambuco       PE  northeast
# 6                Piauí       PI  northeast
# 7  Rio Grande do Norte       RN  northeast
# 8              Sergipe       SE  northeast

# %%
regions_df3 = pd.DataFrame(states_brazil_list['central_west'], columns= ['state','sc_state'])
regions_df3['region']= 'central_west'
regions_df3
# Out:
#                 state sc_state        region
# 0               Goiás       GO  central_west
# 1         Mato Grosso       MT  central_west
# 2  Mato Grosso do Sul       MS  central_west
# 3            Brasília       DF  central_west

# %%
regions_df4 = pd.DataFrame(states_brazil_list['southeast'], columns= ['state','sc_state'])
regions_df4['region']= 'southeast'
regions_df4
# Out:
#             state sc_state     region
# 0  Espírito Santo       ES  southeast
# 1    Minas Gerais       MG  southeast
# 2  Rio de Janeiro       RJ  southeast
# 3       São Paulo       SP  southeast

# %%
regions_df5 = pd.DataFrame(states_brazil_list['south'], columns= ['state','sc_state'])
regions_df5['region']= 'south'
regions_df5
# Out:
#                state sc_state region
# 0             Paraná       PR  south
# 1     Santa Catarina       SC  south
# 2  Rio Grande do Sul       RS  south

# %%
regions_df = pd.concat([regions_df1, regions_df2, regions_df3, regions_df4, regions_df5], ignore_index=True)
regions_df.sample(10)
# Out:
#              state sc_state        region
# 22  Rio de Janeiro       RJ     southeast
# 15         Sergipe       SE     northeast
# 16           Goiás       GO  central_west
# 1            Amapá       AP  north_region
# 9            Ceará       CE     northeast
# 10        Maranhão       MA     northeast
# 24          Paraná       PR         south
# 17     Mato Grosso       MT  central_west
# 12      Pernambuco       PE     northeast
# 6        Tocantins       TO  north_region

# %%
data1_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    zip_code_prefix_customer          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#    geolocation_lat_customer  geolocation_lng_customer
# 0                -20.498489                -47.396929
# 1                -23.727992                -46.542848
# 2                -23.531642                -46.656289
# 3                -23.499702                -46.185233
# 4                -22.975100                -47.142925

# %%
data1_customers = data1_customers.rename(columns={"customer_state": 'sc_state'})

# %%
data1_customers= data1_customers.merge(regions_df, how='outer',on= 'sc_state')

# %%
data1_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    zip_code_prefix_customer          customer_city sc_state  \
# 0                     14409                 franca       SP
# 1                      9790  sao bernardo do campo       SP
# 2                      1151              sao paulo       SP
# 3                      8775        mogi das cruzes       SP
# 4                     13056               campinas       SP
#
#    geolocation_lat_customer  geolocation_lng_customer      state     region
# 0                -20.498489                -47.396929  São Paulo  southeast
# 1                -23.727992                -46.542848  São Paulo  southeast
# 2                -23.531642                -46.656289  São Paulo  southeast
# 3                -23.499702                -46.185233  São Paulo  southeast
# 4                -22.975100                -47.142925  São Paulo  southeast

# %%
data1_customers = data1_customers.rename(columns={'sc_state': 'sc_state_customer','state':'state_customer','region':'region_customer'})

# %%
data8_sellers = data8_sellers.rename(columns={"seller_state": 'sc_state'})

# %%
data8_sellers= data8_sellers.merge(regions_df, how='outer',on= 'sc_state')
data8_sellers.head()
# Out:
#                           seller_id  zip_code_prefix_seller  \
# 0  3442f8959a84dea7ee197c632cb2df15                 13023.0
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                 13844.0
# 2  c0f3eea2e14555b6faeea3dd58c1b1c3                  4195.0
# 3  51a04a8a6bdcb23deccc82b0b80742cf                 12914.0
# 4  1b938a7ec6ac5061a66a3766e0e75f90                 16304.0
#
#          seller_city sc_state  geolocation_lat_seller  geolocation_lng_seller  \
# 0           campinas       SP              -22.893848              -47.061337
# 1         mogi guacu       SP              -22.383437              -46.947927
# 2          sao paulo       SP              -23.657242              -46.612831
# 3  braganca paulista       SP              -22.964803              -46.534419
# 4          penapolis       SP              -21.437403              -50.076931
#
#        state     region
# 0  São Paulo  southeast
# 1  São Paulo  southeast
# 2  São Paulo  southeast
# 3  São Paulo  southeast
# 4  São Paulo  southeast

# %%
data8_sellers = data8_sellers.rename(columns={'sc_state': 'sc_state_seller','state':'state_seller','region':'region_seller'})

# %%
data1_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    zip_code_prefix_customer          customer_city sc_state_customer  \
# 0                     14409                 franca                SP
# 1                      9790  sao bernardo do campo                SP
# 2                      1151              sao paulo                SP
# 3                      8775        mogi das cruzes                SP
# 4                     13056               campinas                SP
#
#    geolocation_lat_customer  geolocation_lng_customer state_customer  \
# 0                -20.498489                -47.396929      São Paulo
# 1                -23.727992                -46.542848      São Paulo
# 2                -23.531642                -46.656289      São Paulo
# 3                -23.499702                -46.185233      São Paulo
# 4                -22.975100                -47.142925      São Paulo
#
#   region_customer
# 0       southeast
# 1       southeast
# 2       southeast
# 3       southeast
# 4       southeast

# %%
data6_orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date  delta_purchase_approved  \
# 0                    2017-10-18                      0.0
# 1                    2018-08-13                     30.0
# 2                    2018-09-04                      0.0
# 3                    2017-12-15                      0.0
# 4                    2018-02-26                      1.0
#
#    delta_purchase_delivered_carrier  delta_purchase_delivered_customer  \
# 0                              56.0                              202.0
# 1                              41.0                              330.0
# 2                               5.0                              225.0
# 3                              90.0                              317.0
# 4                              22.0                               68.0
#
#    delta_delivered_customer_carrier  \
# 0                             145.0
# 1                             288.0
# 2                             220.0
# 3                             226.0
# 4                              46.0
#
#    delta_delivered_customer_order_estimated_delivery_
# 0                                              170.0
# 1                                              128.0
# 2                                              413.0
# 3                                              311.0
# 4                                              221.0

# %% [markdown]
# ## Distance Between Customer and Seller

# %%
customers_orders= data1_customers.merge(data6_orders, how='left',on= 'customer_id')

# %%
customers_orders.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    zip_code_prefix_customer          customer_city sc_state_customer  \
# 0                     14409                 franca                SP
# 1                      9790  sao bernardo do campo                SP
# 2                      1151              sao paulo                SP
# 3                      8775        mogi das cruzes                SP
# 4                     13056               campinas                SP
#
#    geolocation_lat_customer  geolocation_lng_customer state_customer  \
# 0                -20.498489                -47.396929      São Paulo
# 1                -23.727992                -46.542848      São Paulo
# 2                -23.531642                -46.656289      São Paulo
# 3                -23.499702                -46.185233      São Paulo
# 4                -22.975100                -47.142925      São Paulo
#
#   region_customer                          order_id  ...  \
# 0       southeast  00e7ee1b050b8499577073aeb2a297a1  ...
# 1       southeast  29150127e6685892b6eab3eec79f59c7  ...
# 2       southeast  b2059ed67ce144a36e2aa97d2c9e9ad2  ...
# 3       southeast  951670f92359f4fe4a63112aa7306eba  ...
# 4       southeast  6b7d50bd145f6fc7f33cebabd7e49d0f  ...
#
#   order_purchase_timestamp   order_approved_at order_delivered_carrier_date  \
# 0      2017-05-16 15:05:35 2017-05-16 15:22:12          2017-05-23 10:47:57
# 1      2018-01-12 20:48:24 2018-01-12 20:58:32          2018-01-15 17:14:59
# 2      2018-05-19 16:07:45 2018-05-20 16:19:10          2018-06-11 14:31:00
# 3      2018-03-13 16:06:38 2018-03-13 17:29:19          2018-03-27 23:22:42
# 4      2018-07-29 09:51:30 2018-07-29 10:10:09          2018-07-30 15:16:00
#
#   order_delivered_customer_date order_estimated_delivery_date  \
# 0           2017-05-25 10:35:35                    2017-06-05
# 1           2018-01-29 12:41:19                    2018-02-06
# 2           2018-06-14 17:58:51                    2018-06-13
# 3           2018-03-28 16:04:25                    2018-04-10
# 4           2018-08-09 20:55:48                    2018-08-15
#
#   delta_purchase_approved  delta_purchase_delivered_carrier  \
# 0                     0.0                             163.0
# 1                     0.0                              68.0
# 2                    24.0                             550.0
# 3                     1.0                             343.0
# 4                     0.0                              29.0
#
#    delta_purchase_delivered_customer  delta_delivered_customer_carrier  \
# 0                              211.0                              47.0
# 1                              399.0                             331.0
# 2                              625.0                              75.0
# 3                              359.0                              16.0
# 4                              275.0                             245.0
#
#    delta_delivered_customer_order_estimated_delivery_
# 0                                              253.0
# 1                                              179.0
# 2                                              -42.0
# 3                                              295.0
# 4                                              123.0
#
# [5 rows x 21 columns]

# %%
data3_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value shipping_limit_date_only  \
# 0 2017-09-19 09:45:35   58.90          13.29               2017-09-19
# 1 2017-05-03 11:05:13  239.90          19.93               2017-05-03
# 2 2018-01-18 14:48:30  199.00          17.87               2018-01-18
# 3 2018-08-15 10:10:18   12.99          12.79               2018-08-15
# 4 2017-02-13 13:57:51  199.90          18.14               2017-02-13
#
#   shipping_limit_date_hour
# 0                 09:45:35
# 1                 11:05:13
# 2                 14:48:30
# 3                 10:10:18
# 4                 13:57:51

# %%
customers_orders_item = customers_orders.merge(data3_items, how='inner',on= 'order_id')

# %%
customers_orders_item.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    zip_code_prefix_customer          customer_city sc_state_customer  \
# 0                     14409                 franca                SP
# 1                      9790  sao bernardo do campo                SP
# 2                      1151              sao paulo                SP
# 3                      8775        mogi das cruzes                SP
# 4                     13056               campinas                SP
#
#    geolocation_lat_customer  geolocation_lng_customer state_customer  \
# 0                -20.498489                -47.396929      São Paulo
# 1                -23.727992                -46.542848      São Paulo
# 2                -23.531642                -46.656289      São Paulo
# 3                -23.499702                -46.185233      São Paulo
# 4                -22.975100                -47.142925      São Paulo
#
#   region_customer                          order_id  ...  \
# 0       southeast  00e7ee1b050b8499577073aeb2a297a1  ...
# 1       southeast  29150127e6685892b6eab3eec79f59c7  ...
# 2       southeast  b2059ed67ce144a36e2aa97d2c9e9ad2  ...
# 3       southeast  951670f92359f4fe4a63112aa7306eba  ...
# 4       southeast  6b7d50bd145f6fc7f33cebabd7e49d0f  ...
#
#   delta_delivered_customer_carrier  \
# 0                             47.0
# 1                            331.0
# 2                             75.0
# 3                             16.0
# 4                            245.0
#
#   delta_delivered_customer_order_estimated_delivery_ order_item_id  \
# 0                                              253.0             1
# 1                                              179.0             1
# 2                                              -42.0             1
# 3                                              295.0             1
# 4                                              123.0             1
#
#                          product_id                         seller_id  \
# 0  a9516a079e37a9c9c36b9b78b10169e8  7c67e1448b00f6e969d365cea6b010ab
# 1  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 2  bd07b66896d6f1494f5b86251848ced7  7c67e1448b00f6e969d365cea6b010ab
# 3  a5647c44af977b148e0a3a4751a09e2e  7c67e1448b00f6e969d365cea6b010ab
# 4  9391a573abe00141c56e38d84d7d5b3b  4a3ca9315b744ce9f8e9374361493884
#
#   shipping_limit_date   price  freight_value  shipping_limit_date_only  \
# 0 2017-05-22 15:22:12  124.99          21.88                2017-05-22
# 1 2018-01-18 20:58:32  289.00          46.48                2018-01-18
# 2 2018-06-05 16:19:10  139.94          17.79                2018-06-05
# 3 2018-03-27 16:31:16  149.94          23.36                2018-03-27
# 4 2018-07-31 10:10:09  230.00          22.25                2018-07-31
#
#    shipping_limit_date_hour
# 0                  15:22:12
# 1                  20:58:32
# 2                  16:19:10
# 3                  16:31:16
# 4                  10:10:09
#
# [5 rows x 29 columns]

# %%
data8_sellers
# Out:
#                              seller_id  zip_code_prefix_seller  \
# 0     3442f8959a84dea7ee197c632cb2df15                 13023.0
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                 13844.0
# 2     c0f3eea2e14555b6faeea3dd58c1b1c3                  4195.0
# 3     51a04a8a6bdcb23deccc82b0b80742cf                 12914.0
# 4     1b938a7ec6ac5061a66a3766e0e75f90                 16304.0
# ...                                ...                     ...
# 3094  67225bff54a172ff67579aaf583efd78                 85960.0
# 3095                               NaN                     NaN
# 3096                               NaN                     NaN
# 3097                               NaN                     NaN
# 3098                               NaN                     NaN
#
#                   seller_city sc_state_seller  geolocation_lat_seller  \
# 0                    campinas              SP              -22.893848
# 1                  mogi guacu              SP              -22.383437
# 2                   sao paulo              SP              -23.657242
# 3           braganca paulista              SP              -22.964803
# 4                   penapolis              SP              -21.437403
# ...                       ...             ...                     ...
# 3094  marechal candido rondon              PA              -24.554525
# 3095                      NaN              AP                     NaN
# 3096                      NaN              RR                     NaN
# 3097                      NaN              TO                     NaN
# 3098                      NaN              AL                     NaN
#
#       geolocation_lng_seller state_seller region_seller
# 0                 -47.061337    São Paulo     southeast
# 1                 -46.947927    São Paulo     southeast
# 2                 -46.612831    São Paulo     southeast
# 3                 -46.534419    São Paulo     southeast
# 4                 -50.076931    São Paulo     southeast
# ...                      ...          ...           ...
# 3094              -54.058525         Pará  north_region
# 3095                     NaN        Amapá  north_region
# 3096                     NaN      Roraima  north_region
# 3097                     NaN    Tocantins  north_region
# 3098                     NaN      Alagoas     northeast
#
# [3099 rows x 8 columns]

# %%
customers_orders_item_sellers = customers_orders_item.merge(data8_sellers, how='left',on= 'seller_id')

# %%
customers_orders_item_sellers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    zip_code_prefix_customer          customer_city sc_state_customer  \
# 0                     14409                 franca                SP
# 1                      9790  sao bernardo do campo                SP
# 2                      1151              sao paulo                SP
# 3                      8775        mogi das cruzes                SP
# 4                     13056               campinas                SP
#
#    geolocation_lat_customer  geolocation_lng_customer state_customer  \
# 0                -20.498489                -47.396929      São Paulo
# 1                -23.727992                -46.542848      São Paulo
# 2                -23.531642                -46.656289      São Paulo
# 3                -23.499702                -46.185233      São Paulo
# 4                -22.975100                -47.142925      São Paulo
#
#   region_customer                          order_id  ... freight_value  \
# 0       southeast  00e7ee1b050b8499577073aeb2a297a1  ...         21.88
# 1       southeast  29150127e6685892b6eab3eec79f59c7  ...         46.48
# 2       southeast  b2059ed67ce144a36e2aa97d2c9e9ad2  ...         17.79
# 3       southeast  951670f92359f4fe4a63112aa7306eba  ...         23.36
# 4       southeast  6b7d50bd145f6fc7f33cebabd7e49d0f  ...         22.25
#
#   shipping_limit_date_only shipping_limit_date_hour zip_code_prefix_seller  \
# 0               2017-05-22                 15:22:12                 8577.0
# 1               2018-01-18                 20:58:32                88303.0
# 2               2018-06-05                 16:19:10                 8577.0
# 3               2018-03-27                 16:31:16                 8577.0
# 4               2018-07-31                 10:10:09                14940.0
#
#        seller_city sc_state_seller  geolocation_lat_seller  \
# 0  itaquaquecetuba              SP              -23.486111
# 1           itajai              SC              -26.912574
# 2  itaquaquecetuba              SP              -23.486111
# 3  itaquaquecetuba              SP              -23.486111
# 4         ibitinga              SP              -21.757321
#
#    geolocation_lng_seller    state_seller  region_seller
# 0              -46.366721       São Paulo      southeast
# 1              -48.673980  Santa Catarina          south
# 2              -46.366721       São Paulo      southeast
# 3              -46.366721       São Paulo      southeast
# 4              -48.829744       São Paulo      southeast
#
# [5 rows x 36 columns]

# %%
customers_orders_item_sellers['zip_code_prefix_seller'] = customers_orders_item_sellers['zip_code_prefix_seller'].astype('int')

# %%
customers_orders_item_sellers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    zip_code_prefix_customer          customer_city sc_state_customer  \
# 0                     14409                 franca                SP
# 1                      9790  sao bernardo do campo                SP
# 2                      1151              sao paulo                SP
# 3                      8775        mogi das cruzes                SP
# 4                     13056               campinas                SP
#
#    geolocation_lat_customer  geolocation_lng_customer state_customer  \
# 0                -20.498489                -47.396929      São Paulo
# 1                -23.727992                -46.542848      São Paulo
# 2                -23.531642                -46.656289      São Paulo
# 3                -23.499702                -46.185233      São Paulo
# 4                -22.975100                -47.142925      São Paulo
#
#   region_customer                          order_id  ... freight_value  \
# 0       southeast  00e7ee1b050b8499577073aeb2a297a1  ...         21.88
# 1       southeast  29150127e6685892b6eab3eec79f59c7  ...         46.48
# 2       southeast  b2059ed67ce144a36e2aa97d2c9e9ad2  ...         17.79
# 3       southeast  951670f92359f4fe4a63112aa7306eba  ...         23.36
# 4       southeast  6b7d50bd145f6fc7f33cebabd7e49d0f  ...         22.25
#
#   shipping_limit_date_only shipping_limit_date_hour zip_code_prefix_seller  \
# 0               2017-05-22                 15:22:12                   8577
# 1               2018-01-18                 20:58:32                  88303
# 2               2018-06-05                 16:19:10                   8577
# 3               2018-03-27                 16:31:16                   8577
# 4               2018-07-31                 10:10:09                  14940
#
#        seller_city sc_state_seller  geolocation_lat_seller  \
# 0  itaquaquecetuba              SP              -23.486111
# 1           itajai              SC              -26.912574
# 2  itaquaquecetuba              SP              -23.486111
# 3  itaquaquecetuba              SP              -23.486111
# 4         ibitinga              SP              -21.757321
#
#    geolocation_lng_seller    state_seller  region_seller
# 0              -46.366721       São Paulo      southeast
# 1              -48.673980  Santa Catarina          south
# 2              -46.366721       São Paulo      southeast
# 3              -46.366721       São Paulo      southeast
# 4              -48.829744       São Paulo      southeast
#
# [5 rows x 36 columns]

# %%
customers_orders_item_sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110180 entries, 0 to 110179
# Data columns (total 36 columns):
#  #   Column                                              Non-Null Count   Dtype
# ---  ------                                              --------------   -----
#  0   customer_id                                         110180 non-null  object
#  1   customer_unique_id                                  110180 non-null  object
#  2   zip_code_prefix_customer                            110180 non-null  int64
#  3   customer_city                                       110180 non-null  object
#  4   sc_state_customer                                   110180 non-null  object
#  5   geolocation_lat_customer                            109892 non-null  float64
#  6   geolocation_lng_customer                            109892 non-null  float64
#  7   state_customer                                      110180 non-null  object
#  8   region_customer                                     110180 non-null  object
#  9   order_id                                            110180 non-null  object
#  10  order_status                                        110180 non-null  object
#  11  order_purchase_timestamp                            110180 non-null  datetime64[ns]
#  12  order_approved_at                                   110180 non-null  datetime64[ns]
#  13  order_delivered_carrier_date                        110180 non-null  datetime64[ns]
#  14  order_delivered_customer_date                       110180 non-null  datetime64[ns]
#  15  order_estimated_delivery_date                       110180 non-null  datetime64[ns]
#  16  delta_purchase_approved                             110180 non-null  float64
#  17  delta_purchase_delivered_carrier                    110180 non-null  float64
#  18  delta_purchase_delivered_customer                   110180 non-null  float64
#  19  delta_delivered_customer_carrier                    110180 non-null  float64
#  20  delta_delivered_customer_order_estimated_delivery_  110180 non-null  float64
#  21  order_item_id                                       110180 non-null  int64
#  22  product_id                                          110180 non-null  object
#  23  seller_id                                           110180 non-null  object
#  24  shipping_limit_date                                 110180 non-null  datetime64[ns]
#  25  price                                               110180 non-null  float64
#  26  freight_value                                       110180 non-null  float64
#  27  shipping_limit_date_only                            110180 non-null  datetime64[ns]
#  28  shipping_limit_date_hour                            110180 non-null  object
#  29  zip_code_prefix_seller                              110180 non-null  int64
#  30  seller_city                                         110180 non-null  object
#  31  sc_state_seller                                     110180 non-null  object
#  32  geolocation_lat_seller                              109931 non-null  float64
#  33  geolocation_lng_seller                              109931 non-null  float64
#  34  state_seller                                        110180 non-null  object
#  35  region_seller                                       110180 non-null  object
# dtypes: datetime64[ns](7), float64(11), int64(3), object(15)
# memory usage: 31.1+ MB

# %% [markdown]
# ## Calculating Distance Between Buyer and Seller

# %%
def haversine_vectorize(lon1, lat1, lon2, lat2):
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])
    newlon = lon2 - lon1
    newlat = lat2 - lat1
    haver_formula = np.sin(newlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(newlon/2.0)**2
    dist = 2 * np.arcsin(np.sqrt(haver_formula))
    km = 6371 * dist
    return km

customers_orders_item_sellers['dist_in_km'] = round(haversine_vectorize(customers_orders_item_sellers['geolocation_lat_customer'], 
                                             customers_orders_item_sellers['geolocation_lng_customer'],
                                             customers_orders_item_sellers['geolocation_lat_seller'], 
                                             customers_orders_item_sellers['geolocation_lng_seller']), 3)

# %%
customers_orders_item_sellers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    zip_code_prefix_customer          customer_city sc_state_customer  \
# 0                     14409                 franca                SP
# 1                      9790  sao bernardo do campo                SP
# 2                      1151              sao paulo                SP
# 3                      8775        mogi das cruzes                SP
# 4                     13056               campinas                SP
#
#    geolocation_lat_customer  geolocation_lng_customer state_customer  \
# 0                -20.498489                -47.396929      São Paulo
# 1                -23.727992                -46.542848      São Paulo
# 2                -23.531642                -46.656289      São Paulo
# 3                -23.499702                -46.185233      São Paulo
# 4                -22.975100                -47.142925      São Paulo
#
#   region_customer                          order_id  ...  \
# 0       southeast  00e7ee1b050b8499577073aeb2a297a1  ...
# 1       southeast  29150127e6685892b6eab3eec79f59c7  ...
# 2       southeast  b2059ed67ce144a36e2aa97d2c9e9ad2  ...
# 3       southeast  951670f92359f4fe4a63112aa7306eba  ...
# 4       southeast  6b7d50bd145f6fc7f33cebabd7e49d0f  ...
#
#   shipping_limit_date_only shipping_limit_date_hour zip_code_prefix_seller  \
# 0               2017-05-22                 15:22:12                   8577
# 1               2018-01-18                 20:58:32                  88303
# 2               2018-06-05                 16:19:10                   8577
# 3               2018-03-27                 16:31:16                   8577
# 4               2018-07-31                 10:10:09                  14940
#
#        seller_city sc_state_seller geolocation_lat_seller  \
# 0  itaquaquecetuba              SP             -23.486111
# 1           itajai              SC             -26.912574
# 2  itaquaquecetuba              SP             -23.486111
# 3  itaquaquecetuba              SP             -23.486111
# 4         ibitinga              SP             -21.757321
#
#    geolocation_lng_seller    state_seller  region_seller  dist_in_km
# 0              -46.366721       São Paulo      southeast     254.302
# 1              -48.673980  Santa Catarina          south     336.323
# 2              -46.366721       São Paulo      southeast      32.386
# 3              -46.366721       São Paulo      southeast      20.208
# 4              -48.829744       São Paulo      southeast     208.307
#
# [5 rows x 37 columns]

# %%
customers_orders_item_sellers['dist_in_km'].min()
# Out:
# 0.0

# %%
customers_orders_item_sellers['dist_in_km'].max()
# Out:
# 7717.566

# %%
plt.subplots(figsize= (12,5))
sns.histplot(data=customers_orders_item_sellers,x='dist_in_km', bins=80)
plt.xlim(0, 2500)
# Out:
# (0.0, 2500.0)

# %% [markdown]
# Groups per distance between seller and customer.
#
# group_1: 0 - 100
# group_2: 101 - 300
# group_3: 301 - 500
# group_4: 501 - 700
# group_5: 701- 900
# group_6: 901 - 1100
# group_7: 1101 - 1500
# group_8: 1501 - 2000
# group_9: 2000 >

# %%
distance_labels = ['group_1','group_2', 'group_3', 'group_4','group_5','group_6','group_7','group_8','group_9']
bin_boundaries = [   -0.1, 100,    301,       501,       701,      901,      1101,      1501,     2001,    7720 ]

# %%
customers_orders_item_sellers['distance_group']= pd.cut(customers_orders_item_sellers['dist_in_km'], bins=bin_boundaries, labels=distance_labels)

# %%
customers_orders_item_sellers.sample(10)
# Out:
#                              customer_id                customer_unique_id  \
# 89094   f128ed11b295f1d94750deca9a92b354  7bac6eccf7d44be2e87d13a24e1499f4
# 106004  21971b011fe99f0cbb172f4e3fd11f89  e917a8b251d536ef2c470de1cd6a0668
# 62827   eadc11a901ffc9d8b616ac86cf86e666  9b42b36166bfd019e01d36a38ca05073
# 20767   ce0ceb45fe0c526c8b6959f36131687f  dc9844b33771e435cb001b30ae742573
# 57932   259be3b485b1e4c6f3e732d88d673e68  07945f8606e69cb0e43700b586524050
# 61581   d78a5880a2347eb58b1c90069e205694  92fcb692f748f9e8e79b75511f1a59af
# 75245   c5279c1aed890b6931837dda06d188c9  4a8b7c8d02cad7d510a0561c724e755b
# 94960   a5f8960eef588aeaa9d1af800ef40607  2d94b4d76656b186b0b717c23ed66273
# 80504   97ba7ab5636b3e4696989ffb223ff95f  63ec546088a2719f707653ee572c9ae5
# 61955   4b5417e69f8175a0c37bbbbe9d0e1bb8  abc481fdeb66223f47a7d59b78e065fa
#
#         zip_code_prefix_customer       customer_city sc_state_customer  \
# 89094                      94185            gravatai                RS
# 106004                     52041              recife                PE
# 62827                      31655      belo horizonte                MG
# 20767                       9540  sao caetano do sul                SP
# 57932                      37048            varginha                MG
# 61581                      38405          uberlandia                MG
# 75245                      21920      rio de janeiro                RJ
# 94960                      45400             valenca                BA
# 80504                      21210      rio de janeiro                RJ
# 61955                      31520      belo horizonte                MG
#
#         geolocation_lat_customer  geolocation_lng_customer     state_customer  \
# 89094                 -29.945227                -50.971882  Rio Grande do Sul
# 106004                 -8.034194                -34.894814         Pernambuco
# 62827                 -19.789356                -43.984638       Minas Gerais
# 20767                 -23.624968                -46.566194          São Paulo
# 57932                 -21.570497                -45.417847       Minas Gerais
# 61581                 -18.892698                -48.249940       Minas Gerais
# 75245                 -22.798116                -43.195698     Rio de Janeiro
# 94960                 -13.367204                -39.071966              Bahia
# 80504                 -22.843731                -43.302427     Rio de Janeiro
# 61955                 -19.819517                -43.968826       Minas Gerais
#
#        region_customer                          order_id  ...  \
# 89094            south  bbf7ad105edc929937625364891dc8c6  ...
# 106004       northeast  d638d378198797824d3f468baf192ea3  ...
# 62827        southeast  34763d94ee16ecffb979852f4ee83571  ...
# 20767        southeast  64f5fd87174ba865c091f3ceabeaf0e3  ...
# 57932        southeast  09e78337fade609c785bdc87f287a535  ...
# 61581        southeast  37424b4c8096e0738986a1d6fffc6da2  ...
# 75245        southeast  b89b697cf1384ba59f3ce56bc8d28cc6  ...
# 94960        northeast  28509a1c959e460948d32485cac51f9d  ...
# 80504        southeast  bf3aac7b998a34f5bc14f646652e7bed  ...
# 61955        southeast  ca407fb4d0b3cada058f453a973155cc  ...
#
#        shipping_limit_date_hour zip_code_prefix_seller            seller_city  \
# 89094                  12:50:25                   4811              sao paulo
# 106004                 17:34:04                  74645                goiania
# 62827                  19:03:22                   7112              guarulhos
# 20767                  10:14:05                   3470              sao paulo
# 57932                  11:07:40                  13483                limeira
# 61581                  21:29:53                  35700            sete lagoas
# 75245                  20:35:14                  13405             piracicaba
# 94960                  17:14:40                  15041  sao jose do rio preto
# 80504                  08:31:21                  11701           praia grande
# 61955                  20:45:14                  13170                 sumare
#
#        sc_state_seller geolocation_lat_seller geolocation_lng_seller  \
# 89094               SP             -23.710419             -46.693254
# 106004              GO             -16.664457             -49.244693
# 62827               SP             -23.468704             -46.516142
# 20767               SP             -23.569113             -46.522287
# 57932               SP             -22.560755             -47.446494
# 61581               MG             -19.457995             -44.248128
# 75245               SP             -22.708702             -47.664701
# 94960               SP             -20.790374             -49.418262
# 80504               SP             -24.008923             -46.419125
# 61955               SP             -22.822137             -47.270335
#
#         state_seller  region_seller  dist_in_km  distance_group
# 89094      São Paulo      southeast     658.802         group_4
# 106004         Goiás   central_west    1744.682         group_8
# 62827      São Paulo      southeast     402.651         group_3
# 20767      São Paulo      southeast       6.487         group_1
# 57932      São Paulo      southeast     237.994         group_2
# 61581   Minas Gerais      southeast     447.096         group_3
# 75245      São Paulo      southeast     496.979         group_3
# 94960      São Paulo      southeast    1292.007         group_7
# 80504      São Paulo      southeast     358.511         group_3
# 61955      São Paulo      southeast     435.009         group_3
#
# [10 rows x 38 columns]

# %%
customers_orders_item_sellers.isnull().sum()
# Out:
# customer_id                                             0
# customer_unique_id                                      0
# zip_code_prefix_customer                                0
# customer_city                                           0
# sc_state_customer                                       0
# geolocation_lat_customer                              288
# geolocation_lng_customer                              288
# state_customer                                          0
# region_customer                                         0
# order_id                                                0
# order_status                                            0
# order_purchase_timestamp                                0
# order_approved_at                                       0
# order_delivered_carrier_date                            0
# order_delivered_customer_date                           0
# order_estimated_delivery_date                           0
# delta_purchase_approved                                 0
# delta_purchase_delivered_carrier                        0
# delta_purchase_delivered_customer                       0
# delta_delivered_customer_carrier                        0
# delta_delivered_customer_order_estimated_delivery_      0
# order_item_id                                           0
# product_id                                              0
# seller_id                                               0
# shipping_limit_date                                     0
# price                                                   0
# freight_value                                           0
# shipping_limit_date_only                                0
# shipping_limit_date_hour                                0
# zip_code_prefix_seller                                  0
# seller_city                                             0
# sc_state_seller                                         0
# geolocation_lat_seller                                249
# geolocation_lng_seller                                249
# state_seller                                            0
# region_seller                                           0
# dist_in_km                                            536
# distance_group                                        536
# dtype: int64

# %%
customers_orders_item_sellers.count()
# Out:
# customer_id                                           110180
# customer_unique_id                                    110180
# zip_code_prefix_customer                              110180
# customer_city                                         110180
# sc_state_customer                                     110180
# geolocation_lat_customer                              109892
# geolocation_lng_customer                              109892
# state_customer                                        110180
# region_customer                                       110180
# order_id                                              110180
# order_status                                          110180
# order_purchase_timestamp                              110180
# order_approved_at                                     110180
# order_delivered_carrier_date                          110180
# order_delivered_customer_date                         110180
# order_estimated_delivery_date                         110180
# delta_purchase_approved                               110180
# delta_purchase_delivered_carrier                      110180
# delta_purchase_delivered_customer                     110180
# delta_delivered_customer_carrier                      110180
# delta_delivered_customer_order_estimated_delivery_    110180
# order_item_id                                         110180
# product_id                                            110180
# seller_id                                             110180
# shipping_limit_date                                   110180
# price                                                 110180
# freight_value                                         110180
# shipping_limit_date_only                              110180
# shipping_limit_date_hour                              110180
# zip_code_prefix_seller                                110180
# seller_city                                           110180
# sc_state_seller                                       110180
# geolocation_lat_seller                                109931
# geolocation_lng_seller                                109931
# state_seller                                          110180
# region_seller                                         110180
# dist_in_km                                            109644
# distance_group                                        109644
# dtype: int64

# %%
customers_orders_item_sellers.to_csv('data_sets/final_datasets/data_f1_olist.csv', index= False)
